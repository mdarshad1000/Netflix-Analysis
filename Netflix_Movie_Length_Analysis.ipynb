# %% [markdown]
# # Netfllix Movie Length Analysis
#
# We've propesed a null hypothesis that over the years the duration of movies has decreased. We will perform data analysis using advanced techniques to get insights of the data and verify if our proposed hypothesis is true or not.

# %% [markdown]
# ## 1. Loading the data from a CSV
#
# The data that we are loading is in a CSV format which isn't organized and difficult is difficult to read.
#
# Therefore we read the CSV file as a  DataFrame which is easier to inspect.

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b740125a-095a-49cd-b0a5-07481747e812" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b740125a-095a-49cd-b0a5-07481747e812">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving netflix_data.csv to netflix_data.csv

# %%
# Importing Pandas under its conventional alias
import pandas as pd

# Read CSV as a Dataframe
netflix_df = pd.read_csv('netflix_data.csv')

# %% [markdown]
# ## 2. Overview of the data
# We will try to get an overview of the data by inspecting the first and last few rows.
#
# Also, we will try to get an outline of the data by getting through the missing values, name of columns etcetera.

# %%
print(netflix_df)
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#              country          date_added  release_year  duration  \
# 0             Brazil     August 14, 2020          2020         4
# 1             Mexico   December 23, 2016          2016        93
# 2          Singapore   December 20, 2018          2011        78
# 3      United States   November 16, 2017          2009        80
# 4      United States     January 1, 2020          2008       123
# ...              ...                 ...           ...       ...
# 7782          Sweden    October 19, 2020          2005        99
# 7783           India       March 2, 2019          2015       111
# 7784             NaN  September 25, 2020          2019        44
# 7785       Australia    October 31, 2020          2019         1
# 7786  United Kingdom       March 1, 2020          2019        90
#
#                                             description             genre
# 0     In a future where the elite inhabit an island ...  International TV
# 1     After a devastating earthquake hits Mexico Cit...            Dramas
# 2     When an army recruit is found dead, his fellow...     Horror Movies
# 3     In a postapocalyptic world, rag-doll robots hi...            Action
# 4     A brilliant group of students become card-coun...            Dramas
# ...                                                 ...               ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...            Dramas
# 7783  A scrappy but poor boy worms his way into a ty...            Dramas
# 7784  In this documentary, South African rapper Nast...     Documentaries
# 7785  Dessert wizard Adriano Zumbo looks for the nex...  International TV
# 7786  This documentary delves into the mystique behi...     Documentaries
#
# [7787 rows x 11 columns]

# %%
# First five rows
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
#                                          description             genre
# 0  In a future where the elite inhabit an island ...  International TV
# 1  After a devastating earthquake hits Mexico Cit...            Dramas
# 2  When an army recruit is found dead, his fellow...     Horror Movies
# 3  In a postapocalyptic world, rag-doll robots hi...            Action
# 4  A brilliant group of students become card-coun...            Dramas

# %%
# Last five rows
netflix_df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast         country  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...          Sweden
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...           India
# 7784                                            Nasty C             NaN
# 7785                         Adriano Zumbo, Rachel Khoo       Australia
# 7786                                                NaN  United Kingdom
#
#               date_added  release_year  duration  \
# 7782    October 19, 2020          2005        99
# 7783       March 2, 2019          2015       111
# 7784  September 25, 2020          2019        44
# 7785    October 31, 2020          2019         1
# 7786       March 1, 2020          2019        90
#
#                                             description             genre
# 7782  When Lebanon's Civil War deprives Zozo of his ...            Dramas
# 7783  A scrappy but poor boy worms his way into a ty...            Dramas
# 7784  In this documentary, South African rapper Nast...     Documentaries
# 7785  Dessert wizard Adriano Zumbo looks for the nex...  International TV
# 7786  This documentary delves into the mystique behi...     Documentaries

# %%
# Missing values in each column
netflix_df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# duration           0
# description        0
# genre              0
# dtype: int64

# %%
# Name of columns
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %% [markdown]
# ## 3. Filtering the Movies
# To find if or null hypothesis stands correct or not, we will start with scatching a surface to move towards our objective

# %%
# Extracting only movies from the data
netflix_movie_df = netflix_df[netflix_df['type'] == 'Movie'] 

# Selecting only the columns of interest
netflix_movies_subset_df = netflix_movie_df.loc[:, ['title', 'country', 'genre', 'release_year', 'duration']]

# The new dataset
netflix_movies_subset_df.head()
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
# Importing dependency to make figures
import matplotlib.pyplot as plt

# Create a figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
_ = plt.scatter(netflix_movies_subset_df['release_year'], netflix_movies_subset_df['duration'])
_ = plt.title('Movies Duration by Year of Release')
_ = plt.xlabel('Year')
_ = plt.ylabel('Movie Duration')
# Display the Plot
_ = plt.show()

# %% [markdown]
# ## 4. Digging deeper
# From the plot we can see that a lot of movies of shorter duration were released majorly in the last decade or so. Also that newer movies are published more on the platform compared to the old ones.
#
# On further analysis, we can see that a decent amount of movies are as short as being under 1 hour. Let's filter our DataFrame for movies with a duration under 60 minutes and look at the genres. This might give us an understanding on what exactly is dragging down the average.

# %%
# Movies shroter than 1 hour
short_movies = netflix_movies_subset_df[netflix_movies_subset_df['duration']<60]

# Print the first few enteries of the short movie DataFrame
print(short_movies.head(30))

# Print the last few enteries of the short movie DataFrame
print(short_movies.head(30))
# Out:
#                                                  title         country  \
# 35                                           #Rucker50   United States
# 55                 100 Things to do Before High School   United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava 
# 237                             A Tale of Two Kitchens   United States
# 242                            A Trash Truck Christmas             NaN
# 247                            A Very Murray Christmas   United States
# 285                               Abominable Christmas   United States
# 295                                 Across Grace Alley   United States
# 305                Adam Devine: Best Time of Our Lives   United States
# 310                       Adel Karam: Live from Beirut   United States
# 325                                        After Maria   United States
# 328                                     After the Raid   United States
# 342          Aggretsuko: We Wish You a Metal Christmas           Japan
# 370                     Alan Saldaña: Mi vida de pobre          Mexico
# 378     Alex Fernández: The Best Comedian in the World          Mexico
# 390                    Alias JJ, la celebridad del mal             NaN
# 399                                         Alien Xmas   United States
# 414                                   All In My Family   United States
# 432           Alpha and Omega 2: A Howl-iday Adventure   United States
#
#              genre  release_year  duration
# 35   Documentaries          2016        56
# 55   Uncategorized          2014        44
# 67   Uncategorized          2017        37
# 101  Documentaries          2018        53
# 146  Documentaries          2019        28
# 162  Uncategorized          2016        22
# 171  Uncategorized          2019        29
# 177       Children          2020        22
# 178       Children          2020        22
# 179       Children          2020        21
# 181  Documentaries          2015        59
# 200  Documentaries          2020        20
# 220       Stand-Up          2011        44
# 233       Children          2017        26
# 237  Documentaries          2019        30
# 242       Children          2020        28
# 247       Comedies          2015        57
# 285       Children          2012        44
# 295         Dramas          2013        24
# 305       Stand-Up          2019        59
# 310       Stand-Up          2018        59
# 325  Documentaries          2019        38
# 328  Documentaries          2019        25
# 342  Uncategorized          2018        22
# 370       Stand-Up          2017        54
# 378       Stand-Up          2020        51
# 390  Documentaries          2017        54
# 399       Children          2020        42
# 414  Documentaries          2019        40
# 432       Children          2013        45

# %% [markdown]
# ## 5. Marking and Plotting Features
# It is interesting to find out that many movies which are under 60 minutes long fall under the genre "Children", "Stand-Up", and "Documentaries".
#
# Now we can plot these values to understand the distribution within these genres.

# %%
# Define an empty list 
colours = []

# Iterate over rows of "genre" column in the DataFrame
for item in netflix_movies_subset_df['genre']:

  if item == 'Children':
    colours.append('Red')

  elif item == 'Documentaries':
    colours.append('Blue')
  
  elif item == 'Stand-Up':
    colours.append('Green')
  
  else:
    colours.append('Gray')

# %%
# Setting figure style and size
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of release year vs duration
plt.scatter(netflix_movies_subset_df['release_year'], netflix_movies_subset_df['duration'], c=colours)
plt.title('Movies duration by year of release')
plt.xlabel('Year')
plt.ylabel('Duration (min')

# Show the plot
plt.show()

# %% [markdown]
# ## 6. Conclusion
# Well as we suspected, the non traditional genres such as children's movies and documentaries are all clustered around the bottom half of the plot, signifying short movie length. But we can't be so sure until we perform further analysis.
#
# Our null hypothesis stands incorrect as the duration of the movies haven't necessarily decreased over the years. Although we can see that the number of movies of shorter duration are clustered towards the last decade or so, but that doesn't mean that movies of longer duration aren't released anymore.
#
# To conclude: By the turn of the previous decade, there was a sudden surge in the release of movies of shorter duration. But this did not effect the releases of movies of longer duration.
